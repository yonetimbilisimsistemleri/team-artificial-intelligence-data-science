# %%
import time 
from selenium import webdriver
import webbrowser
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import requests

# %%
baslik = "iphone"
#baslik = input("aranan değer: ")
url = "https://www.sikayetvar.com/sikayetler"
browser = webdriver.Chrome()

time.sleep(4)
browser.get(url)
print("url açıldı")
input_area = browser.find_element(By.ID,"text-autocomplete")
print("arama butonu bulundu")
browser.maximize_window()
print("tam ekran yapıldı")

input_area.send_keys(baslik)
print("arama yerine key gönderildi")
button = browser.find_element(By.XPATH,"//*[@id='header-autocomplete']/button")
print("button bulundu")
button.click()
print("butona tıklandı")
time.sleep(4)

url = browser.current_url
source = browser.page_source
soup = BeautifulSoup(source, "html.parser")
print("url,source,soup atandı")
print(url)
#//*[@id="main-content"]/div[1]/div[2]/article[7]/section
#//*[@id="main-content"]/div[1]/div[2]/article[8]/section
page_count = soup.find("div", {"class": "pagination-wrap"}).find("ul", {"class": "pagination ga-v ga-c"}).find_all("li")[6].get_text(strip=True)
#eğer son sayfa numarasının yeri sabit olsaydı buradan yapabilirdik
#sayfa = browser.find_element(By.XPATH,"//*[@id='main-content']/div[1]/div[2]/div[9]/ul/li[7]")
sayfa = int(page_count)
print("sayfa sayısı:" , sayfa)
articles = browser.find_elements(By.TAG_NAME,"article")
for page in range(2,sayfa+1):
    response = requests.get(url + baslik +"?page=" )#str(i), headers=headers
    #print(url + "?p=" + str(i))
    time.sleep(2)
    for article in articles:
        sections = article.find_elements(By.TAG_NAME, "section")
        for section in sections:
                a_element = section.find_element(By.TAG_NAME, "a")
        text = a_element.text
        print("Başlık: ",text)
        print("*******************************************************************************")
        # section içindeki p etiketindeki metni al
        p_element = section.find_element(By.TAG_NAME, "p")
        text = p_element.text
        print("Şikayet: ",text)
        print("*******************************************************************************")
        
        
   
    


print("6")
#browser.close()
# Out:
# url açıldı
# arama butonu bulundu
# tam ekran yapıldı
# arama yerine key gönderildi
# button bulundu
# butona tıklandı
# url,source,soup atandı
# https://www.sikayetvar.com/sikayetler
# sayfa sayısı: 350
# Başlık:  Sendeo Kargom Teslim Edildi Gözüküyor Ama Edilmedi
# *******************************************************************************
# Şikayet:  Sendeo isimli kargo firması kargoyu teslim etmediği halde teslim edildi gözüküyor kargo bana ulaşmadı, kargom nerede, kimde bilmiyorum aramadığım müşteri temsilcisi görüşmediğim canlı destek kalmadı, hepsi talep oluşturuyoruz diyor sonuç yok yardımcı olun kargo takip numaram: 238643819556
# *******************************************************************************
# Başlık:  Exxen, Üye Olmadığım Ve İstemediğim Halde Kartımdan Para Çekiyor!
# *******************************************************************************
# Şikayet:  Exxen veya exen her ne ise işte; bu digital platform firması kredi kartımdan haberim olmadan para çekmeye çalışıyor. Üstelik de ben burada şaibeli olduğu aşikar firmaya/platforma üye de değilim, olmak da istemedim. Ben televizyon kullanan biri de değilim. Bankayı aradım, exen firmasının 49.90 TL tut...
# *******************************************************************************
# Başlık:  Exxen İade Olmasına Rağmen Para Çekmesi
# *******************************************************************************
# Şikayet:  Exxen aboneliği çok önceden iptal etmeme rağmen halen daha kartımdan para çekiyor kartıma para geldiğinde anında çekim yapıyor bu 1 kere değil 3-4 kere oldu sıkıldım bu durumdan gerçekten paramın geri iadesini talep ediyorum daha kaç defa iptal edeceğim anlamıyorum bıktırdın Exxen gerçekten
# *******************************************************************************
# Başlık:  Exxen'i İptal Ettim Ödeme Almaya Devam Ediyor.
# *******************************************************************************
# Şikayet:  Exxen üyeliğimi iptal ettiğim halde ödeme almaya devam ediyor, arıyorum mail atın bildirin diyorlar, mail attım defalarca, dönen olmadı, iade istiyorum, Exxen izlemiyorum, iade et iptal sonrası aldığınız ödemeleri. Exxen izlemiyorum artık ödeme alma benden, aldıklarını iade et.
# *******************************************************************************
# Başlık:  Aras Kargo Zil Çalışmıyor Evde Olduğum Halde Ürünümü Teslim Alamadım
# *******************************************************************************
# Şikayet:  Ben evde olduğum halde ürün bana teslim edilmedi zil çalışmıyor beni hiçbir şekilde aramadılar mesaj gönderdiler ürününüz teslim olmadı dediler evde olduğum halde ürünümü alamadım ne yapmalıyım şube bana çok uzak gidemiyorum ikiz bebeklerim var
# Bana yardımcı ol
# *******************************************************************************
# Başlık:  Bitay Hesaba Tl Ödemesini Geciktiriyor
# *******************************************************************************
# Şikayet:  Bitay da bulunan bakiyemi çekebilmek için yatırım da bulundum. Para yatırma işlemim hızlı gerçekleşti fakat konu para çekmeye geldiğinde diğer borsalar ile karıştırmayın arkadaşlar yaklaşık olarak 45 dakikadır hala onay bekliyor para çekim talebim yani yatırırım hemen hızlıca çekerim zannediyorsanız...
# *******************************************************************************
# Başlık:  Akbank Google YDS Şüpheli Para Çekimi
# *******************************************************************************
# Şikayet:  Akbank banka kartımdan bilgim dışında telefonla aranıp onay sorulduğunda reddetmeme rağmen hesabımdan 2004 ₺ çekildi. Akbank hesap hareketlerimde ''Google YDS Yurt dışı satış işlemi'' yazmakta. Banka harcama itiraz formu iletti, doldurdum mail olarak ilettim. Banka kartımı ve kredi kartımı bloke ett...
# *******************************************************************************
# Başlık:  VakıfBank Deprem Kredisi Başvurusu Sistemde Yapılmamış Görünüyor.
# *******************************************************************************
# Şikayet:  VakıfBank'tan deprem kredisine başvurdum. Şubeye gittim sabah 9.39 dan akşam 17.10 a kadar sıra bekledim gereken evrakları teslim ettim. Ancak yaptığım sorgulamada başvurunuz bulunmamaktadır cevabı aldım. Siz benim yerimde olsanız ne yapardınız şu an da başvurular bitti.
# *******************************************************************************
# Başlık:  Hepsiburada Sürekli Teslimat Yapılan Adrese Ürün Teslimatının Yapılmayacak Olması
# *******************************************************************************
# Şikayet:  Teslimat adresi olarak yıllardır alışveriş yaptığım site, Aras Kargo acentesi ile aldığım ürünleri adresime teslim etmekteydi. Yine Aras Kargo ile gönderdiği ürünü kargo şubesinden alınız deniliyor. Bulunduğum ilçede Aras Kargo şubesi var ve evime çok yakın neden ürünü alırken şubeden teslim alınaca...
# *******************************************************************************
# Başlık:  Hepsiburada Sürekli Teslimat Yapılan Adrese Ürün Teslimatının Yapılmayacak Olması
# *******************************************************************************
# Şikayet:  Teslimat adresi olarak yıllardır alışveriş yaptığım site, Aras Kargo acentesi ile aldığım ürünleri adresime teslim etmekteydi. Yine Aras Kargo ile gönderdiği ürünü kargo şubesinden alınız deniliyor. Bulunduğum ilçede Aras Kargo şubesi var ve evime çok yakın neden ürünü alırken şubeden teslim alınaca...
# *******************************************************************************
# Başlık:  VakıfBank Mobil Bankacılık Üzerinden Kredi Başvurusu Yapamıyorum
# *******************************************************************************
# Şikayet:  Vakıf Mobilden kredi limitim (sky limit) yeterli olmasına rağmen işlem yaptığımda "VakıfBank işleminizi bu kanaldan gerçekleştiremiyoruz" gibi bir hatayla karşılaşıyorum. VakıfBank Mobil hayatımızı kolaylaştırmayacaksa neden var? Lütfen şu soruna el atın, eminim ben gibi çok müşteri vardır.
# *******************************************************************************
# Başlık:  QNB Finansbank Yıllık Üyelik Ücreti
# *******************************************************************************
# Şikayet:  5824 ile biten kredi kartımdan 2022 yılında yıllık üyelik ücreti adı altında 252 TL olarak hesaba borç yansıtılmıştır. Bu haksız kart ücretinin iadesini istiyorum. Alınan yersiz ve kanunsuz bedelin, aşağıda belirtilen kanun hükümleri gereği koşulsuz, şartsız iptal edilerek tarafıma bilgi verilmesini...
# *******************************************************************************
# Başlık:  Papara Şifre Hatası Limiti Uyarısı
# *******************************************************************************
# Şikayet:  Papara kartıma para yatırmak istedim fakat Maximum şifre deneme hatası veriyor. Tekrar doğru şifreyi girsem işlem yapabilir miyim? Yoksa aramam mı gerekiyor? Doğru şifreyi şu an hatırladım aradan 1 hafta geçti işlem yaparken yine aynı hatayı verir mi?
# *******************************************************************************
# Başlık:  Papara Param Hesabıma Geçmedi
# *******************************************************************************
# Şikayet:  Papara hesabıma param geçmedi 19.43 Ziraat hesabımdan 115 TL para gönderdim ama ne yazık ki Papara'ya hala geçmedi. WhatsApp destek hattı hiçbir şekilde ilgilenmiyor. Mail attım cevap yok konuyla ilgili acil ilgilenilmesini istiyorum hemen zor durumda kalıyorum.
# *******************************************************************************
# Başlık:  Akbank Kartı Şikayet Oldu
# *******************************************************************************
# Şikayet:  Akbank kredi kartı yeni adres vermeme rağmen eski adrese teslim edildi bana haber verilmedi. Teslimatım bir şekilde yapılmış fakat bilgim dahilinde olmadı. Bu dönem de yapılan harcamalarımı mecbur nakit yapmak zorunda kaldım. Akbank pişmanlıktır pişman oldum yeniden kredi kartı çıkardığım içim
# *******************************************************************************
# Başlık:  Monster Bilgisayarın Sürekli Arızalanması
# *******************************************************************************
# Şikayet:  2023ün aralık ayında bir bilgisayar aldım. Çevremi de etkisiyle Monster ı tercih ettim. Bu bilgisayarı almak için babama çok ısrar etmiştim. Çünkü güzel projeler tasarlayacaktım. 2 güzel proje tasarladım ikisi de Monster bilgisayarımın sürekli arıza yapması sonucu battı. Defalarca servise verdim ama...
# *******************************************************************************
# Başlık:  Monster Bilgisayarın Sürekli Arızalanması
# *******************************************************************************
# Şikayet:  2023ün aralık ayında bir bilgisayar aldım. Çevremi de etkisiyle Monster ı tercih ettim. Bu bilgisayarı almak için babama çok ısrar etmiştim. Çünkü güzel projeler tasarlayacaktım. 2 güzel proje tasarladım ikisi de Monster bilgisayarımın sürekli arıza yapması sonucu battı. Defalarca servise verdim ama...
# *******************************************************************************
# Başlık:  Monster Bilgisayarın Sürekli Arızalanması
# *******************************************************************************
# Şikayet:  2023ün aralık ayında bir bilgisayar aldım. Çevremi de etkisiyle Monster ı tercih ettim. Bu bilgisayarı almak için babama çok ısrar etmiştim. Çünkü güzel projeler tasarlayacaktım. 2 güzel proje tasarladım ikisi de Monster bilgisayarımın sürekli arıza yapması sonucu battı. Defalarca servise verdim ama...
# *******************************************************************************
# Başlık:  Aras Kargo Mağduriyeti Ve Uğrattığı Zararlar!
# *******************************************************************************
# Şikayet:  Aras Kargo Dalaman şubesi sürekli bir mağduriyet yaşatıyor! Trendyol ve Hepsiburada üzerinden satış yapıyoruz. Tüm kargolarımızı Aras Kargo ile gönderiyoruz ve sürekli bir hata ile karşılaşıyoruz. Yanlış deside kesilen kargolar! Kesmeyi unuttukları kargolar! Kaybettikleri kargolar! Dehşete kapıldığı...
# *******************************************************************************
# Başlık:  MNG Kargo Gaziantep Yeditepe Şubesi Kargomu Kaybetti
# *******************************************************************************
# Şikayet:  MNG Kargo (Gaziantep-Yeditepe şubesi) kargomu kayıp etti. Kargomu 2022 aralık ayında kayıp ettiklerini kabul ettiler. Sonra bir Forum imzalamamı söylediler. Ücret iadesi süreci başladı ve beni arayacaklarını söylediler. Daha sonra aramadılar ve e-posta adresime ücret iadesi kabul olmuştur mesajı gel...
# *******************************************************************************
# Başlık:  VakıfBank Market Kampanyası Puan Yatırmadı
# *******************************************************************************
# Şikayet:  VakıfBank şubat ayı kredi kartı market kampanyasına katıldım. 7 ayrı market alışverişi yaptım 500 lira her bir alışveriş. Ama maalesef puan yatmamış. İlk işlem de puan verilmiyordu. Kalan 6 işlem için 120 puanımın kredi kartıma yatırılmasını istiyorum teşekkürler.
# *******************************************************************************
# Başlık:  Sendeo Kargom Teslim Edildi Gözüküyor Ama Edilmedi
# *******************************************************************************
# Şikayet:  Sendeo isimli kargo firması kargoyu teslim etmediği halde teslim edildi gözüküyor kargo bana ulaşmadı, kargom nerede, kimde bilmiyorum aramadığım müşteri temsilcisi görüşmediğim canlı destek kalmadı, hepsi talep oluşturuyoruz diyor sonuç yok yardımcı olun kargo takip numaram: 238643819556
# *******************************************************************************
# Başlık:  Exxen, Üye Olmadığım Ve İstemediğim Halde Kartımdan Para Çekiyor!
# *******************************************************************************
# Şikayet:  Exxen veya exen her ne ise işte; bu digital platform firması kredi kartımdan haberim olmadan para çekmeye çalışıyor. Üstelik de ben burada şaibeli olduğu aşikar firmaya/platforma üye de değilim, olmak da istemedim. Ben televizyon kullanan biri de değilim. Bankayı aradım, exen firmasının 49.90 TL tut...
# *******************************************************************************
# Başlık:  Exxen İade Olmasına Rağmen Para Çekmesi
# *******************************************************************************
# Şikayet:  Exxen aboneliği çok önceden iptal etmeme rağmen halen daha kartımdan para çekiyor kartıma para geldiğinde anında çekim yapıyor bu 1 kere değil 3-4 kere oldu sıkıldım bu durumdan gerçekten paramın geri iadesini talep ediyorum daha kaç defa iptal edeceğim anlamıyorum bıktırdın Exxen gerçekten
# *******************************************************************************
# Başlık:  Exxen'i İptal Ettim Ödeme Almaya Devam Ediyor.
# *******************************************************************************
# Şikayet:  Exxen üyeliğimi iptal ettiğim halde ödeme almaya devam ediyor, arıyorum mail atın bildirin diyorlar, mail attım defalarca, dönen olmadı, iade istiyorum, Exxen izlemiyorum, iade et iptal sonrası aldığınız ödemeleri. Exxen izlemiyorum artık ödeme alma benden, aldıklarını iade et.
# *******************************************************************************
# Başlık:  Aras Kargo Zil Çalışmıyor Evde Olduğum Halde Ürünümü Teslim Alamadım
# *******************************************************************************
# Şikayet:  Ben evde olduğum halde ürün bana teslim edilmedi zil çalışmıyor beni hiçbir şekilde aramadılar mesaj gönderdiler ürününüz teslim olmadı dediler evde olduğum halde ürünümü alamadım ne yapmalıyım şube bana çok uzak gidemiyorum ikiz bebeklerim var
# Bana yardımcı ol
# *******************************************************************************
# Başlık:  Bitay Hesaba Tl Ödemesini Geciktiriyor
# *******************************************************************************
# Şikayet:  Bitay da bulunan bakiyemi çekebilmek için yatırım da bulundum. Para yatırma işlemim hızlı gerçekleşti fakat konu para çekmeye geldiğinde diğer borsalar ile karıştırmayın arkadaşlar yaklaşık olarak 45 dakikadır hala onay bekliyor para çekim talebim yani yatırırım hemen hızlıca çekerim zannediyorsanız...
# *******************************************************************************
# Başlık:  Akbank Google YDS Şüpheli Para Çekimi
# *******************************************************************************
# Şikayet:  Akbank banka kartımdan bilgim dışında telefonla aranıp onay sorulduğunda reddetmeme rağmen hesabımdan 2004 ₺ çekildi. Akbank hesap hareketlerimde ''Google YDS Yurt dışı satış işlemi'' yazmakta. Banka harcama itiraz formu iletti, doldurdum mail olarak ilettim. Banka kartımı ve kredi kartımı bloke ett...
# *******************************************************************************
# Başlık:  VakıfBank Deprem Kredisi Başvurusu Sistemde Yapılmamış Görünüyor.
# *******************************************************************************
# Şikayet:  VakıfBank'tan deprem kredisine başvurdum. Şubeye gittim sabah 9.39 dan akşam 17.10 a kadar sıra bekledim gereken evrakları teslim ettim. Ancak yaptığım sorgulamada başvurunuz bulunmamaktadır cevabı aldım. Siz benim yerimde olsanız ne yapardınız şu an da başvurular bitti.
# *******************************************************************************
# Başlık:  Hepsiburada Sürekli Teslimat Yapılan Adrese Ürün Teslimatının Yapılmayacak Olması
# *******************************************************************************
# Şikayet:  Teslimat adresi olarak yıllardır alışveriş yaptığım site, Aras Kargo acentesi ile aldığım ürünleri adresime teslim etmekteydi. Yine Aras Kargo ile gönderdiği ürünü kargo şubesinden alınız deniliyor. Bulunduğum ilçede Aras Kargo şubesi var ve evime çok yakın neden ürünü alırken şubeden teslim alınaca...
# *******************************************************************************
# Başlık:  Hepsiburada Sürekli Teslimat Yapılan Adrese Ürün Teslimatının Yapılmayacak Olması
# *******************************************************************************
# Şikayet:  Teslimat adresi olarak yıllardır alışveriş yaptığım site, Aras Kargo acentesi ile aldığım ürünleri adresime teslim etmekteydi. Yine Aras Kargo ile gönderdiği ürünü kargo şubesinden alınız deniliyor. Bulunduğum ilçede Aras Kargo şubesi var ve evime çok yakın neden ürünü alırken şubeden teslim alınaca...
# *******************************************************************************
# Başlık:  VakıfBank Mobil Bankacılık Üzerinden Kredi Başvurusu Yapamıyorum
# *******************************************************************************
# Şikayet:  Vakıf Mobilden kredi limitim (sky limit) yeterli olmasına rağmen işlem yaptığımda "VakıfBank işleminizi bu kanaldan gerçekleştiremiyoruz" gibi bir hatayla karşılaşıyorum. VakıfBank Mobil hayatımızı kolaylaştırmayacaksa neden var? Lütfen şu soruna el atın, eminim ben gibi çok müşteri vardır.
# *******************************************************************************
# Başlık:  QNB Finansbank Yıllık Üyelik Ücreti
# *******************************************************************************
# Şikayet:  5824 ile biten kredi kartımdan 2022 yılında yıllık üyelik ücreti adı altında 252 TL olarak hesaba borç yansıtılmıştır. Bu haksız kart ücretinin iadesini istiyorum. Alınan yersiz ve kanunsuz bedelin, aşağıda belirtilen kanun hükümleri gereği koşulsuz, şartsız iptal edilerek tarafıma bilgi verilmesini...
# *******************************************************************************
# Başlık:  Papara Şifre Hatası Limiti Uyarısı
# *******************************************************************************
# Şikayet:  Papara kartıma para yatırmak istedim fakat Maximum şifre deneme hatası veriyor. Tekrar doğru şifreyi girsem işlem yapabilir miyim? Yoksa aramam mı gerekiyor? Doğru şifreyi şu an hatırladım aradan 1 hafta geçti işlem yaparken yine aynı hatayı verir mi?
# *******************************************************************************
# Başlık:  Papara Param Hesabıma Geçmedi
# *******************************************************************************
# Şikayet:  Papara hesabıma param geçmedi 19.43 Ziraat hesabımdan 115 TL para gönderdim ama ne yazık ki Papara'ya hala geçmedi. WhatsApp destek hattı hiçbir şekilde ilgilenmiyor. Mail attım cevap yok konuyla ilgili acil ilgilenilmesini istiyorum hemen zor durumda kalıyorum.
# *******************************************************************************
# Başlık:  Akbank Kartı Şikayet Oldu
# *******************************************************************************
# Şikayet:  Akbank kredi kartı yeni adres vermeme rağmen eski adrese teslim edildi bana haber verilmedi. Teslimatım bir şekilde yapılmış fakat bilgim dahilinde olmadı. Bu dönem de yapılan harcamalarımı mecbur nakit yapmak zorunda kaldım. Akbank pişmanlıktır pişman oldum yeniden kredi kartı çıkardığım içim
# *******************************************************************************
# Başlık:  Monster Bilgisayarın Sürekli Arızalanması
# *******************************************************************************
# Şikayet:  2023ün aralık ayında bir bilgisayar aldım. Çevremi de etkisiyle Monster ı tercih ettim. Bu bilgisayarı almak için babama çok ısrar etmiştim. Çünkü güzel projeler tasarlayacaktım. 2 güzel proje tasarladım ikisi de Monster bilgisayarımın sürekli arıza yapması sonucu battı. Defalarca servise verdim ama...
# *******************************************************************************
# Başlık:  Monster Bilgisayarın Sürekli Arızalanması
# *******************************************************************************
# Şikayet:  2023ün aralık ayında bir bilgisayar aldım. Çevremi de etkisiyle Monster ı tercih ettim. Bu bilgisayarı almak için babama çok ısrar etmiştim. Çünkü güzel projeler tasarlayacaktım. 2 güzel proje tasarladım ikisi de Monster bilgisayarımın sürekli arıza yapması sonucu battı. Defalarca servise verdim ama...
# *******************************************************************************
# Başlık:  Monster Bilgisayarın Sürekli Arızalanması
# *******************************************************************************
# Şikayet:  2023ün aralık ayında bir bilgisayar aldım. Çevremi de etkisiyle Monster ı tercih ettim. Bu bilgisayarı almak için babama çok ısrar etmiştim. Çünkü güzel projeler tasarlayacaktım. 2 güzel proje tasarladım ikisi de Monster bilgisayarımın sürekli arıza yapması sonucu battı. Defalarca servise verdim ama...
# *******************************************************************************
# Başlık:  Aras Kargo Mağduriyeti Ve Uğrattığı Zararlar!
# *******************************************************************************
# Şikayet:  Aras Kargo Dalaman şubesi sürekli bir mağduriyet yaşatıyor! Trendyol ve Hepsiburada üzerinden satış yapıyoruz. Tüm kargolarımızı Aras Kargo ile gönderiyoruz ve sürekli bir hata ile karşılaşıyoruz. Yanlış deside kesilen kargolar! Kesmeyi unuttukları kargolar! Kaybettikleri kargolar! Dehşete kapıldığı...
# *******************************************************************************
# Başlık:  MNG Kargo Gaziantep Yeditepe Şubesi Kargomu Kaybetti
# *******************************************************************************
# Şikayet:  MNG Kargo (Gaziantep-Yeditepe şubesi) kargomu kayıp etti. Kargomu 2022 aralık ayında kayıp ettiklerini kabul ettiler. Sonra bir Forum imzalamamı söylediler. Ücret iadesi süreci başladı ve beni arayacaklarını söylediler. Daha sonra aramadılar ve e-posta adresime ücret iadesi kabul olmuştur mesajı gel...
# *******************************************************************************
# Başlık:  VakıfBank Market Kampanyası Puan Yatırmadı
# *******************************************************************************
# Şikayet:  VakıfBank şubat ayı kredi kartı market kampanyasına katıldım. 7 ayrı market alışverişi yaptım 500 lira her bir alışveriş. Ama maalesef puan yatmamış. İlk işlem de puan verilmiyordu. Kalan 6 işlem için 120 puanımın kredi kartıma yatırılmasını istiyorum teşekkürler.
# *******************************************************************************
# Başlık:  Sendeo Kargom Teslim Edildi Gözüküyor Ama Edilmedi
# *******************************************************************************
# Şikayet:  Sendeo isimli kargo firması kargoyu teslim etmediği halde teslim edildi gözüküyor kargo bana ulaşmadı, kargom nerede, kimde bilmiyorum aramadığım müşteri temsilcisi görüşmediğim canlı destek kalmadı, hepsi talep oluşturuyoruz diyor sonuç yok yardımcı olun kargo takip numaram: 238643819556
# *******************************************************************************
# Başlık:  Exxen, Üye Olmadığım Ve İstemediğim Halde Kartımdan Para Çekiyor!
# *******************************************************************************
# Şikayet:  Exxen veya exen her ne ise işte; bu digital platform firması kredi kartımdan haberim olmadan para çekmeye çalışıyor. Üstelik de ben burada şaibeli olduğu aşikar firmaya/platforma üye de değilim, olmak da istemedim. Ben televizyon kullanan biri de değilim. Bankayı aradım, exen firmasının 49.90 TL tut...
# *******************************************************************************
# Başlık:  Exxen İade Olmasına Rağmen Para Çekmesi
# *******************************************************************************
# Şikayet:  Exxen aboneliği çok önceden iptal etmeme rağmen halen daha kartımdan para çekiyor kartıma para geldiğinde anında çekim yapıyor bu 1 kere değil 3-4 kere oldu sıkıldım bu durumdan gerçekten paramın geri iadesini talep ediyorum daha kaç defa iptal edeceğim anlamıyorum bıktırdın Exxen gerçekten
# *******************************************************************************
# Başlık:  Exxen'i İptal Ettim Ödeme Almaya Devam Ediyor.
# *******************************************************************************
# Şikayet:  Exxen üyeliğimi iptal ettiğim halde ödeme almaya devam ediyor, arıyorum mail atın bildirin diyorlar, mail attım defalarca, dönen olmadı, iade istiyorum, Exxen izlemiyorum, iade et iptal sonrası aldığınız ödemeleri. Exxen izlemiyorum artık ödeme alma benden, aldıklarını iade et.
# *******************************************************************************
# Başlık:  Aras Kargo Zil Çalışmıyor Evde Olduğum Halde Ürünümü Teslim Alamadım
# *******************************************************************************
# Şikayet:  Ben evde olduğum halde ürün bana teslim edilmedi zil çalışmıyor beni hiçbir şekilde aramadılar mesaj gönderdiler ürününüz teslim olmadı dediler evde olduğum halde ürünümü alamadım ne yapmalıyım şube bana çok uzak gidemiyorum ikiz bebeklerim var
# Bana yardımcı ol
# *******************************************************************************
# Başlık:  Bitay Hesaba Tl Ödemesini Geciktiriyor
# *******************************************************************************
# Şikayet:  Bitay da bulunan bakiyemi çekebilmek için yatırım da bulundum. Para yatırma işlemim hızlı gerçekleşti fakat konu para çekmeye geldiğinde diğer borsalar ile karıştırmayın arkadaşlar yaklaşık olarak 45 dakikadır hala onay bekliyor para çekim talebim yani yatırırım hemen hızlıca çekerim zannediyorsanız...
# *******************************************************************************
# Başlık:  Akbank Google YDS Şüpheli Para Çekimi
# *******************************************************************************
# Şikayet:  Akbank banka kartımdan bilgim dışında telefonla aranıp onay sorulduğunda reddetmeme rağmen hesabımdan 2004 ₺ çekildi. Akbank hesap hareketlerimde ''Google YDS Yurt dışı satış işlemi'' yazmakta. Banka harcama itiraz formu iletti, doldurdum mail olarak ilettim. Banka kartımı ve kredi kartımı bloke ett...
# *******************************************************************************
# Başlık:  VakıfBank Deprem Kredisi Başvurusu Sistemde Yapılmamış Görünüyor.
# *******************************************************************************
# Şikayet:  VakıfBank'tan deprem kredisine başvurdum. Şubeye gittim sabah 9.39 dan akşam 17.10 a kadar sıra bekledim gereken evrakları teslim ettim. Ancak yaptığım sorgulamada başvurunuz bulunmamaktadır cevabı aldım. Siz benim yerimde olsanız ne yapardınız şu an da başvurular bitti.
# *******************************************************************************
# Başlık:  Hepsiburada Sürekli Teslimat Yapılan Adrese Ürün Teslimatının Yapılmayacak Olması
# *******************************************************************************
# Şikayet:  Teslimat adresi olarak yıllardır alışveriş yaptığım site, Aras Kargo acentesi ile aldığım ürünleri adresime teslim etmekteydi. Yine Aras Kargo ile gönderdiği ürünü kargo şubesinden alınız deniliyor. Bulunduğum ilçede Aras Kargo şubesi var ve evime çok yakın neden ürünü alırken şubeden teslim alınaca...
# *******************************************************************************
# Başlık:  Hepsiburada Sürekli Teslimat Yapılan Adrese Ürün Teslimatının Yapılmayacak Olması
# *******************************************************************************
# Şikayet:  Teslimat adresi olarak yıllardır alışveriş yaptığım site, Aras Kargo acentesi ile aldığım ürünleri adresime teslim etmekteydi. Yine Aras Kargo ile gönderdiği ürünü kargo şubesinden alınız deniliyor. Bulunduğum ilçede Aras Kargo şubesi var ve evime çok yakın neden ürünü alırken şubeden teslim alınaca...
# *******************************************************************************
# Başlık:  VakıfBank Mobil Bankacılık Üzerinden Kredi Başvurusu Yapamıyorum
# *******************************************************************************
# Şikayet:  Vakıf Mobilden kredi limitim (sky limit) yeterli olmasına rağmen işlem yaptığımda "VakıfBank işleminizi bu kanaldan gerçekleştiremiyoruz" gibi bir hatayla karşılaşıyorum. VakıfBank Mobil hayatımızı kolaylaştırmayacaksa neden var? Lütfen şu soruna el atın, eminim ben gibi çok müşteri vardır.
# *******************************************************************************
# Başlık:  QNB Finansbank Yıllık Üyelik Ücreti
# *******************************************************************************
# Şikayet:  5824 ile biten kredi kartımdan 2022 yılında yıllık üyelik ücreti adı altında 252 TL olarak hesaba borç yansıtılmıştır. Bu haksız kart ücretinin iadesini istiyorum. Alınan yersiz ve kanunsuz bedelin, aşağıda belirtilen kanun hükümleri gereği koşulsuz, şartsız iptal edilerek tarafıma bilgi verilmesini...
# *******************************************************************************
# Başlık:  Papara Şifre Hatası Limiti Uyarısı
# *******************************************************************************
# Şikayet:  Papara kartıma para yatırmak istedim fakat Maximum şifre deneme hatası veriyor. Tekrar doğru şifreyi girsem işlem yapabilir miyim? Yoksa aramam mı gerekiyor? Doğru şifreyi şu an hatırladım aradan 1 hafta geçti işlem yaparken yine aynı hatayı verir mi?
# *******************************************************************************
# Başlık:  Papara Param Hesabıma Geçmedi
# *******************************************************************************
# Şikayet:  Papara hesabıma param geçmedi 19.43 Ziraat hesabımdan 115 TL para gönderdim ama ne yazık ki Papara'ya hala geçmedi. WhatsApp destek hattı hiçbir şekilde ilgilenmiyor. Mail attım cevap yok konuyla ilgili acil ilgilenilmesini istiyorum hemen zor durumda kalıyorum.
# *******************************************************************************
# Başlık:  Akbank Kartı Şikayet Oldu
# *******************************************************************************
# Şikayet:  Akbank kredi kartı yeni adres vermeme rağmen eski adrese teslim edildi bana haber verilmedi. Teslimatım bir şekilde yapılmış fakat bilgim dahilinde olmadı. Bu dönem de yapılan harcamalarımı mecbur nakit yapmak zorunda kaldım. Akbank pişmanlıktır pişman oldum yeniden kredi kartı çıkardığım içim
# *******************************************************************************
# Başlık:  Monster Bilgisayarın Sürekli Arızalanması
# *******************************************************************************
# Şikayet:  2023ün aralık ayında bir bilgisayar aldım. Çevremi de etkisiyle Monster ı tercih ettim. Bu bilgisayarı almak için babama çok ısrar etmiştim. Çünkü güzel projeler tasarlayacaktım. 2 güzel proje tasarladım ikisi de Monster bilgisayarımın sürekli arıza yapması sonucu battı. Defalarca servise verdim ama...
# *******************************************************************************
# Başlık:  Monster Bilgisayarın Sürekli Arızalanması
# *******************************************************************************
# Şikayet:  2023ün aralık ayında bir bilgisayar aldım. Çevremi de etkisiyle Monster ı tercih ettim. Bu bilgisayarı almak için babama çok ısrar etmiştim. Çünkü güzel projeler tasarlayacaktım. 2 güzel proje tasarladım ikisi de Monster bilgisayarımın sürekli arıza yapması sonucu battı. Defalarca servise verdim ama...
# *******************************************************************************
# Başlık:  Monster Bilgisayarın Sürekli Arızalanması
# *******************************************************************************
# Şikayet:  2023ün aralık ayında bir bilgisayar aldım. Çevremi de etkisiyle Monster ı tercih ettim. Bu bilgisayarı almak için babama çok ısrar etmiştim. Çünkü güzel projeler tasarlayacaktım. 2 güzel proje tasarladım ikisi de Monster bilgisayarımın sürekli arıza yapması sonucu battı. Defalarca servise verdim ama...
# *******************************************************************************
# Başlık:  Aras Kargo Mağduriyeti Ve Uğrattığı Zararlar!
# *******************************************************************************
# Şikayet:  Aras Kargo Dalaman şubesi sürekli bir mağduriyet yaşatıyor! Trendyol ve Hepsiburada üzerinden satış yapıyoruz. Tüm kargolarımızı Aras Kargo ile gönderiyoruz ve sürekli bir hata ile karşılaşıyoruz. Yanlış deside kesilen kargolar! Kesmeyi unuttukları kargolar! Kaybettikleri kargolar! Dehşete kapıldığı...
# *******************************************************************************
# Başlık:  MNG Kargo Gaziantep Yeditepe Şubesi Kargomu Kaybetti
# *******************************************************************************
# Şikayet:  MNG Kargo (Gaziantep-Yeditepe şubesi) kargomu kayıp etti. Kargomu 2022 aralık ayında kayıp ettiklerini kabul ettiler. Sonra bir Forum imzalamamı söylediler. Ücret iadesi süreci başladı ve beni arayacaklarını söylediler. Daha sonra aramadılar ve e-posta adresime ücret iadesi kabul olmuştur mesajı gel...
# *******************************************************************************
# Başlık:  VakıfBank Market Kampanyası Puan Yatırmadı
# *******************************************************************************
# Şikayet:  VakıfBank şubat ayı kredi kartı market kampanyasına katıldım. 7 ayrı market alışverişi yaptım 500 lira her bir alışveriş. Ama maalesef puan yatmamış. İlk işlem de puan verilmiyordu. Kalan 6 işlem için 120 puanımın kredi kartıma yatırılmasını istiyorum teşekkürler.
# *******************************************************************************
# Başlık:  Sendeo Kargom Teslim Edildi Gözüküyor Ama Edilmedi
# *******************************************************************************
# Şikayet:  Sendeo isimli kargo firması kargoyu teslim etmediği halde teslim edildi gözüküyor kargo bana ulaşmadı, kargom nerede, kimde bilmiyorum aramadığım müşteri temsilcisi görüşmediğim canlı destek kalmadı, hepsi talep oluşturuyoruz diyor sonuç yok yardımcı olun kargo takip numaram: 238643819556
# *******************************************************************************
# Başlık:  Exxen, Üye Olmadığım Ve İstemediğim Halde Kartımdan Para Çekiyor!
# *******************************************************************************
# Şikayet:  Exxen veya exen her ne ise işte; bu digital platform firması kredi kartımdan haberim olmadan para çekmeye çalışıyor. Üstelik de ben burada şaibeli olduğu aşikar firmaya/platforma üye de değilim, olmak da istemedim. Ben televizyon kullanan biri de değilim. Bankayı aradım, exen firmasının 49.90 TL tut...
# *******************************************************************************
# Başlık:  Exxen İade Olmasına Rağmen Para Çekmesi
# *******************************************************************************
# Şikayet:  Exxen aboneliği çok önceden iptal etmeme rağmen halen daha kartımdan para çekiyor kartıma para geldiğinde anında çekim yapıyor bu 1 kere değil 3-4 kere oldu sıkıldım bu durumdan gerçekten paramın geri iadesini talep ediyorum daha kaç defa iptal edeceğim anlamıyorum bıktırdın Exxen gerçekten
# *******************************************************************************
# Başlık:  Exxen'i İptal Ettim Ödeme Almaya Devam Ediyor.
# *******************************************************************************
# Şikayet:  Exxen üyeliğimi iptal ettiğim halde ödeme almaya devam ediyor, arıyorum mail atın bildirin diyorlar, mail attım defalarca, dönen olmadı, iade istiyorum, Exxen izlemiyorum, iade et iptal sonrası aldığınız ödemeleri. Exxen izlemiyorum artık ödeme alma benden, aldıklarını iade et.
# *******************************************************************************
# Başlık:  Aras Kargo Zil Çalışmıyor Evde Olduğum Halde Ürünümü Teslim Alamadım
# *******************************************************************************
# Şikayet:  Ben evde olduğum halde ürün bana teslim edilmedi zil çalışmıyor beni hiçbir şekilde aramadılar mesaj gönderdiler ürününüz teslim olmadı dediler evde olduğum halde ürünümü alamadım ne yapmalıyım şube bana çok uzak gidemiyorum ikiz bebeklerim var
# Bana yardımcı ol
# *******************************************************************************
# Başlık:  Bitay Hesaba Tl Ödemesini Geciktiriyor
# *******************************************************************************
# Şikayet:  Bitay da bulunan bakiyemi çekebilmek için yatırım da bulundum. Para yatırma işlemim hızlı gerçekleşti fakat konu para çekmeye geldiğinde diğer borsalar ile karıştırmayın arkadaşlar yaklaşık olarak 45 dakikadır hala onay bekliyor para çekim talebim yani yatırırım hemen hızlıca çekerim zannediyorsanız...
# *******************************************************************************
# Başlık:  Akbank Google YDS Şüpheli Para Çekimi
# *******************************************************************************
# Şikayet:  Akbank banka kartımdan bilgim dışında telefonla aranıp onay sorulduğunda reddetmeme rağmen hesabımdan 2004 ₺ çekildi. Akbank hesap hareketlerimde ''Google YDS Yurt dışı satış işlemi'' yazmakta. Banka harcama itiraz formu iletti, doldurdum mail olarak ilettim. Banka kartımı ve kredi kartımı bloke ett...
# *******************************************************************************
# Başlık:  VakıfBank Deprem Kredisi Başvurusu Sistemde Yapılmamış Görünüyor.
# *******************************************************************************
# Şikayet:  VakıfBank'tan deprem kredisine başvurdum. Şubeye gittim sabah 9.39 dan akşam 17.10 a kadar sıra bekledim gereken evrakları teslim ettim. Ancak yaptığım sorgulamada başvurunuz bulunmamaktadır cevabı aldım. Siz benim yerimde olsanız ne yapardınız şu an da başvurular bitti.
# *******************************************************************************
# Başlık:  Hepsiburada Sürekli Teslimat Yapılan Adrese Ürün Teslimatının Yapılmayacak Olması
# *******************************************************************************
# Şikayet:  Teslimat adresi olarak yıllardır alışveriş yaptığım site, Aras Kargo acentesi ile aldığım ürünleri adresime teslim etmekteydi. Yine Aras Kargo ile gönderdiği ürünü kargo şubesinden alınız deniliyor. Bulunduğum ilçede Aras Kargo şubesi var ve evime çok yakın neden ürünü alırken şubeden teslim alınaca...
# *******************************************************************************
# Başlık:  Hepsiburada Sürekli Teslimat Yapılan Adrese Ürün Teslimatının Yapılmayacak Olması
# *******************************************************************************
# Şikayet:  Teslimat adresi olarak yıllardır alışveriş yaptığım site, Aras Kargo acentesi ile aldığım ürünleri adresime teslim etmekteydi. Yine Aras Kargo ile gönderdiği ürünü kargo şubesinden alınız deniliyor. Bulunduğum ilçede Aras Kargo şubesi var ve evime çok yakın neden ürünü alırken şubeden teslim alınaca...
# *******************************************************************************
# Başlık:  VakıfBank Mobil Bankacılık Üzerinden Kredi Başvurusu Yapamıyorum
# *******************************************************************************
# Şikayet:  Vakıf Mobilden kredi limitim (sky limit) yeterli olmasına rağmen işlem yaptığımda "VakıfBank işleminizi bu kanaldan gerçekleştiremiyoruz" gibi bir hatayla karşılaşıyorum. VakıfBank Mobil hayatımızı kolaylaştırmayacaksa neden var? Lütfen şu soruna el atın, eminim ben gibi çok müşteri vardır.
# *******************************************************************************
# Başlık:  QNB Finansbank Yıllık Üyelik Ücreti
# *******************************************************************************
# Şikayet:  5824 ile biten kredi kartımdan 2022 yılında yıllık üyelik ücreti adı altında 252 TL olarak hesaba borç yansıtılmıştır. Bu haksız kart ücretinin iadesini istiyorum. Alınan yersiz ve kanunsuz bedelin, aşağıda belirtilen kanun hükümleri gereği koşulsuz, şartsız iptal edilerek tarafıma bilgi verilmesini...
# *******************************************************************************
# Başlık:  Papara Şifre Hatası Limiti Uyarısı
# *******************************************************************************
# Şikayet:  Papara kartıma para yatırmak istedim fakat Maximum şifre deneme hatası veriyor. Tekrar doğru şifreyi girsem işlem yapabilir miyim? Yoksa aramam mı gerekiyor? Doğru şifreyi şu an hatırladım aradan 1 hafta geçti işlem yaparken yine aynı hatayı verir mi?
# *******************************************************************************
# Başlık:  Papara Param Hesabıma Geçmedi
# *******************************************************************************
# Şikayet:  Papara hesabıma param geçmedi 19.43 Ziraat hesabımdan 115 TL para gönderdim ama ne yazık ki Papara'ya hala geçmedi. WhatsApp destek hattı hiçbir şekilde ilgilenmiyor. Mail attım cevap yok konuyla ilgili acil ilgilenilmesini istiyorum hemen zor durumda kalıyorum.
# *******************************************************************************
# Başlık:  Akbank Kartı Şikayet Oldu
# *******************************************************************************
# Şikayet:  Akbank kredi kartı yeni adres vermeme rağmen eski adrese teslim edildi bana haber verilmedi. Teslimatım bir şekilde yapılmış fakat bilgim dahilinde olmadı. Bu dönem de yapılan harcamalarımı mecbur nakit yapmak zorunda kaldım. Akbank pişmanlıktır pişman oldum yeniden kredi kartı çıkardığım içim
# *******************************************************************************
# Başlık:  Monster Bilgisayarın Sürekli Arızalanması
# *******************************************************************************
# Şikayet:  2023ün aralık ayında bir bilgisayar aldım. Çevremi de etkisiyle Monster ı tercih ettim. Bu bilgisayarı almak için babama çok ısrar etmiştim. Çünkü güzel projeler tasarlayacaktım. 2 güzel proje tasarladım ikisi de Monster bilgisayarımın sürekli arıza yapması sonucu battı. Defalarca servise verdim ama...
# *******************************************************************************
# Başlık:  Monster Bilgisayarın Sürekli Arızalanması
# *******************************************************************************
# Şikayet:  2023ün aralık ayında bir bilgisayar aldım. Çevremi de etkisiyle Monster ı tercih ettim. Bu bilgisayarı almak için babama çok ısrar etmiştim. Çünkü güzel projeler tasarlayacaktım. 2 güzel proje tasarladım ikisi de Monster bilgisayarımın sürekli arıza yapması sonucu battı. Defalarca servise verdim ama...
# *******************************************************************************
# Başlık:  Monster Bilgisayarın Sürekli Arızalanması
# *******************************************************************************
# Şikayet:  2023ün aralık ayında bir bilgisayar aldım. Çevremi de etkisiyle Monster ı tercih ettim. Bu bilgisayarı almak için babama çok ısrar etmiştim. Çünkü güzel projeler tasarlayacaktım. 2 güzel proje tasarladım ikisi de Monster bilgisayarımın sürekli arıza yapması sonucu battı. Defalarca servise verdim ama...
# *******************************************************************************
# Başlık:  Aras Kargo Mağduriyeti Ve Uğrattığı Zararlar!
# *******************************************************************************
# Şikayet:  Aras Kargo Dalaman şubesi sürekli bir mağduriyet yaşatıyor! Trendyol ve Hepsiburada üzerinden satış yapıyoruz. Tüm kargolarımızı Aras Kargo ile gönderiyoruz ve sürekli bir hata ile karşılaşıyoruz. Yanlış deside kesilen kargolar! Kesmeyi unuttukları kargolar! Kaybettikleri kargolar! Dehşete kapıldığı...
# *******************************************************************************
# Başlık:  MNG Kargo Gaziantep Yeditepe Şubesi Kargomu Kaybetti
# *******************************************************************************
# Şikayet:  MNG Kargo (Gaziantep-Yeditepe şubesi) kargomu kayıp etti. Kargomu 2022 aralık ayında kayıp ettiklerini kabul ettiler. Sonra bir Forum imzalamamı söylediler. Ücret iadesi süreci başladı ve beni arayacaklarını söylediler. Daha sonra aramadılar ve e-posta adresime ücret iadesi kabul olmuştur mesajı gel...
# *******************************************************************************
# Başlık:  VakıfBank Market Kampanyası Puan Yatırmadı
# *******************************************************************************
# Şikayet:  VakıfBank şubat ayı kredi kartı market kampanyasına katıldım. 7 ayrı market alışverişi yaptım 500 lira her bir alışveriş. Ama maalesef puan yatmamış. İlk işlem de puan verilmiyordu. Kalan 6 işlem için 120 puanımın kredi kartıma yatırılmasını istiyorum teşekkürler.
# *******************************************************************************
# Başlık:  Sendeo Kargom Teslim Edildi Gözüküyor Ama Edilmedi
# *******************************************************************************
# Şikayet:  Sendeo isimli kargo firması kargoyu teslim etmediği halde teslim edildi gözüküyor kargo bana ulaşmadı, kargom nerede, kimde bilmiyorum aramadığım müşteri temsilcisi görüşmediğim canlı destek kalmadı, hepsi talep oluşturuyoruz diyor sonuç yok yardımcı olun kargo takip numaram: 238643819556
# *******************************************************************************
# Başlık:  Exxen, Üye Olmadığım Ve İstemediğim Halde Kartımdan Para Çekiyor!
# *******************************************************************************
# Şikayet:  Exxen veya exen her ne ise işte; bu digital platform firması kredi kartımdan haberim olmadan para çekmeye çalışıyor. Üstelik de ben burada şaibeli olduğu aşikar firmaya/platforma üye de değilim, olmak da istemedim. Ben televizyon kullanan biri de değilim. Bankayı aradım, exen firmasının 49.90 TL tut...
# *******************************************************************************
# Başlık:  Exxen İade Olmasına Rağmen Para Çekmesi
# *******************************************************************************
# Şikayet:  Exxen aboneliği çok önceden iptal etmeme rağmen halen daha kartımdan para çekiyor kartıma para geldiğinde anında çekim yapıyor bu 1 kere değil 3-4 kere oldu sıkıldım bu durumdan gerçekten paramın geri iadesini talep ediyorum daha kaç defa iptal edeceğim anlamıyorum bıktırdın Exxen gerçekten
# *******************************************************************************
# Başlık:  Exxen'i İptal Ettim Ödeme Almaya Devam Ediyor.
# *******************************************************************************
# Şikayet:  Exxen üyeliğimi iptal ettiğim halde ödeme almaya devam ediyor, arıyorum mail atın bildirin diyorlar, mail attım defalarca, dönen olmadı, iade istiyorum, Exxen izlemiyorum, iade et iptal sonrası aldığınız ödemeleri. Exxen izlemiyorum artık ödeme alma benden, aldıklarını iade et.
# *******************************************************************************
# Başlık:  Aras Kargo Zil Çalışmıyor Evde Olduğum Halde Ürünümü Teslim Alamadım
# *******************************************************************************
# Şikayet:  Ben evde olduğum halde ürün bana teslim edilmedi zil çalışmıyor beni hiçbir şekilde aramadılar mesaj gönderdiler ürününüz teslim olmadı dediler evde olduğum halde ürünümü alamadım ne yapmalıyım şube bana çok uzak gidemiyorum ikiz bebeklerim var
# Bana yardımcı ol
# *******************************************************************************
# Başlık:  Bitay Hesaba Tl Ödemesini Geciktiriyor
# *******************************************************************************
# Şikayet:  Bitay da bulunan bakiyemi çekebilmek için yatırım da bulundum. Para yatırma işlemim hızlı gerçekleşti fakat konu para çekmeye geldiğinde diğer borsalar ile karıştırmayın arkadaşlar yaklaşık olarak 45 dakikadır hala onay bekliyor para çekim talebim yani yatırırım hemen hızlıca çekerim zannediyorsanız...
# *******************************************************************************
# Başlık:  Akbank Google YDS Şüpheli Para Çekimi
# *******************************************************************************
# Şikayet:  Akbank banka kartımdan bilgim dışında telefonla aranıp onay sorulduğunda reddetmeme rağmen hesabımdan 2004 ₺ çekildi. Akbank hesap hareketlerimde ''Google YDS Yurt dışı satış işlemi'' yazmakta. Banka harcama itiraz formu iletti, doldurdum mail olarak ilettim. Banka kartımı ve kredi kartımı bloke ett...
# *******************************************************************************
# Başlık:  VakıfBank Deprem Kredisi Başvurusu Sistemde Yapılmamış Görünüyor.
# *******************************************************************************
# Şikayet:  VakıfBank'tan deprem kredisine başvurdum. Şubeye gittim sabah 9.39 dan akşam 17.10 a kadar sıra bekledim gereken evrakları teslim ettim. Ancak yaptığım sorgulamada başvurunuz bulunmamaktadır cevabı aldım. Siz benim yerimde olsanız ne yapardınız şu an da başvurular bitti.
# *******************************************************************************
# ...
# *******************************************************************************
# Başlık:  Aras Kargo Mağduriyeti Ve Uğrattığı Zararlar!
# *******************************************************************************
# Şikayet:  Aras Kargo Dalaman şubesi sürekli bir mağduriyet yaşatıyor! Trendyol ve Hepsiburada üzerinden satış yapıyoruz. Tüm kargolarımızı Aras Kargo ile gönderiyoruz ve sürekli bir hata ile karşılaşıyoruz. Yanlış deside kesilen kargolar! Kesmeyi unuttukları kargolar! Kaybettikleri kargolar! Dehşete kapıldığı...
# *******************************************************************************
# Başlık:  MNG Kargo Gaziantep Yeditepe Şubesi Kargomu Kaybetti
# *******************************************************************************
# Şikayet:  MNG Kargo (Gaziantep-Yeditepe şubesi) kargomu kayıp etti. Kargomu 2022 aralık ayında kayıp ettiklerini kabul ettiler. Sonra bir Forum imzalamamı söylediler. Ücret iadesi süreci başladı ve beni arayacaklarını söylediler. Daha sonra aramadılar ve e-posta adresime ücret iadesi kabul olmuştur mesajı gel...
# *******************************************************************************
# Başlık:  VakıfBank Market Kampanyası Puan Yatırmadı
# *******************************************************************************
# Şikayet:  VakıfBank şubat ayı kredi kartı market kampanyasına katıldım. 7 ayrı market alışverişi yaptım 500 lira her bir alışveriş. Ama maalesef puan yatmamış. İlk işlem de puan verilmiyordu. Kalan 6 işlem için 120 puanımın kredi kartıma yatırılmasını istiyorum teşekkürler.
# *******************************************************************************
# Başlık:  Sendeo Kargom Teslim Edildi Gözüküyor Ama Edilmedi
# *******************************************************************************
# Şikayet:  Sendeo isimli kargo firması kargoyu teslim etmediği halde teslim edildi gözüküyor kargo bana ulaşmadı, kargom nerede, kimde bilmiyorum aramadığım müşteri temsilcisi görüşmediğim canlı destek kalmadı, hepsi talep oluşturuyoruz diyor sonuç yok yardımcı olun kargo takip numaram: 238643819556
# *******************************************************************************
# Başlık:  Exxen, Üye Olmadığım Ve İstemediğim Halde Kartımdan Para Çekiyor!
# *******************************************************************************
# Şikayet:  Exxen veya exen her ne ise işte; bu digital platform firması kredi kartımdan haberim olmadan para çekmeye çalışıyor. Üstelik de ben burada şaibeli olduğu aşikar firmaya/platforma üye de değilim, olmak da istemedim. Ben televizyon kullanan biri de değilim. Bankayı aradım, exen firmasının 49.90 TL tut...
# *******************************************************************************
# Başlık:  Exxen İade Olmasına Rağmen Para Çekmesi
# *******************************************************************************
# Şikayet:  Exxen aboneliği çok önceden iptal etmeme rağmen halen daha kartımdan para çekiyor kartıma para geldiğinde anında çekim yapıyor bu 1 kere değil 3-4 kere oldu sıkıldım bu durumdan gerçekten paramın geri iadesini talep ediyorum daha kaç defa iptal edeceğim anlamıyorum bıktırdın Exxen gerçekten
# *******************************************************************************
# Başlık:  Exxen'i İptal Ettim Ödeme Almaya Devam Ediyor.
# *******************************************************************************
# Şikayet:  Exxen üyeliğimi iptal ettiğim halde ödeme almaya devam ediyor, arıyorum mail atın bildirin diyorlar, mail attım defalarca, dönen olmadı, iade istiyorum, Exxen izlemiyorum, iade et iptal sonrası aldığınız ödemeleri. Exxen izlemiyorum artık ödeme alma benden, aldıklarını iade et.
# *******************************************************************************
# Başlık:  Aras Kargo Zil Çalışmıyor Evde Olduğum Halde Ürünümü Teslim Alamadım
# *******************************************************************************
# Şikayet:  Ben evde olduğum halde ürün bana teslim edilmedi zil çalışmıyor beni hiçbir şekilde aramadılar mesaj gönderdiler ürününüz teslim olmadı dediler evde olduğum halde ürünümü alamadım ne yapmalıyım şube bana çok uzak gidemiyorum ikiz bebeklerim var
# Bana yardımcı ol
# *******************************************************************************
# Başlık:  Bitay Hesaba Tl Ödemesini Geciktiriyor
# *******************************************************************************
# Şikayet:  Bitay da bulunan bakiyemi çekebilmek için yatırım da bulundum. Para yatırma işlemim hızlı gerçekleşti fakat konu para çekmeye geldiğinde diğer borsalar ile karıştırmayın arkadaşlar yaklaşık olarak 45 dakikadır hala onay bekliyor para çekim talebim yani yatırırım hemen hızlıca çekerim zannediyorsanız...
# *******************************************************************************
# Başlık:  Akbank Google YDS Şüpheli Para Çekimi
# *******************************************************************************
# Şikayet:  Akbank banka kartımdan bilgim dışında telefonla aranıp onay sorulduğunda reddetmeme rağmen hesabımdan 2004 ₺ çekildi. Akbank hesap hareketlerimde ''Google YDS Yurt dışı satış işlemi'' yazmakta. Banka harcama itiraz formu iletti, doldurdum mail olarak ilettim. Banka kartımı ve kredi kartımı bloke ett...
# *******************************************************************************
# Başlık:  VakıfBank Deprem Kredisi Başvurusu Sistemde Yapılmamış Görünüyor.
# *******************************************************************************
# Şikayet:  VakıfBank'tan deprem kredisine başvurdum. Şubeye gittim sabah 9.39 dan akşam 17.10 a kadar sıra bekledim gereken evrakları teslim ettim. Ancak yaptığım sorgulamada başvurunuz bulunmamaktadır cevabı aldım. Siz benim yerimde olsanız ne yapardınız şu an da başvurular bitti.
# *******************************************************************************
# Başlık:  Hepsiburada Sürekli Teslimat Yapılan Adrese Ürün Teslimatının Yapılmayacak Olması
# *******************************************************************************
# Şikayet:  Teslimat adresi olarak yıllardır alışveriş yaptığım site, Aras Kargo acentesi ile aldığım ürünleri adresime teslim etmekteydi. Yine Aras Kargo ile gönderdiği ürünü kargo şubesinden alınız deniliyor. Bulunduğum ilçede Aras Kargo şubesi var ve evime çok yakın neden ürünü alırken şubeden teslim alınaca...
# *******************************************************************************
# Başlık:  Hepsiburada Sürekli Teslimat Yapılan Adrese Ürün Teslimatının Yapılmayacak Olması
# *******************************************************************************
# Şikayet:  Teslimat adresi olarak yıllardır alışveriş yaptığım site, Aras Kargo acentesi ile aldığım ürünleri adresime teslim etmekteydi. Yine Aras Kargo ile gönderdiği ürünü kargo şubesinden alınız deniliyor. Bulunduğum ilçede Aras Kargo şubesi var ve evime çok yakın neden ürünü alırken şubeden teslim alınaca...
# *******************************************************************************
# Başlık:  VakıfBank Mobil Bankacılık Üzerinden Kredi Başvurusu Yapamıyorum
# *******************************************************************************
# Şikayet:  Vakıf Mobilden kredi limitim (sky limit) yeterli olmasına rağmen işlem yaptığımda "VakıfBank işleminizi bu kanaldan gerçekleştiremiyoruz" gibi bir hatayla karşılaşıyorum. VakıfBank Mobil hayatımızı kolaylaştırmayacaksa neden var? Lütfen şu soruna el atın, eminim ben gibi çok müşteri vardır.
# *******************************************************************************
# Başlık:  QNB Finansbank Yıllık Üyelik Ücreti
# *******************************************************************************
# Şikayet:  5824 ile biten kredi kartımdan 2022 yılında yıllık üyelik ücreti adı altında 252 TL olarak hesaba borç yansıtılmıştır. Bu haksız kart ücretinin iadesini istiyorum. Alınan yersiz ve kanunsuz bedelin, aşağıda belirtilen kanun hükümleri gereği koşulsuz, şartsız iptal edilerek tarafıma bilgi verilmesini...
# *******************************************************************************
# Başlık:  Papara Şifre Hatası Limiti Uyarısı
# *******************************************************************************
# Şikayet:  Papara kartıma para yatırmak istedim fakat Maximum şifre deneme hatası veriyor. Tekrar doğru şifreyi girsem işlem yapabilir miyim? Yoksa aramam mı gerekiyor? Doğru şifreyi şu an hatırladım aradan 1 hafta geçti işlem yaparken yine aynı hatayı verir mi?
# *******************************************************************************
# Başlık:  Papara Param Hesabıma Geçmedi
# *******************************************************************************
# Şikayet:  Papara hesabıma param geçmedi 19.43 Ziraat hesabımdan 115 TL para gönderdim ama ne yazık ki Papara'ya hala geçmedi. WhatsApp destek hattı hiçbir şekilde ilgilenmiyor. Mail attım cevap yok konuyla ilgili acil ilgilenilmesini istiyorum hemen zor durumda kalıyorum.
# *******************************************************************************
# Başlık:  Akbank Kartı Şikayet Oldu
# *******************************************************************************
# Şikayet:  Akbank kredi kartı yeni adres vermeme rağmen eski adrese teslim edildi bana haber verilmedi. Teslimatım bir şekilde yapılmış fakat bilgim dahilinde olmadı. Bu dönem de yapılan harcamalarımı mecbur nakit yapmak zorunda kaldım. Akbank pişmanlıktır pişman oldum yeniden kredi kartı çıkardığım içim
# *******************************************************************************
# Başlık:  Monster Bilgisayarın Sürekli Arızalanması
# *******************************************************************************
# Şikayet:  2023ün aralık ayında bir bilgisayar aldım. Çevremi de etkisiyle Monster ı tercih ettim. Bu bilgisayarı almak için babama çok ısrar etmiştim. Çünkü güzel projeler tasarlayacaktım. 2 güzel proje tasarladım ikisi de Monster bilgisayarımın sürekli arıza yapması sonucu battı. Defalarca servise verdim ama...
# *******************************************************************************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17568\2528273612.py in <module>
#      41         for section in sections:
#      42                 a_element = section.find_element(By.TAG_NAME, "a")
# ---> 43         text = a_element.text
#      44         print("Başlık: ",text)
#      45         print("*******************************************************************************")
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py in text(self)
#      87     def text(self) -> str:
#      88         """The text of the element."""
# ---> 89         return self._execute(Command.GET_ELEMENT_TEXT)["value"]
#      90
#      91     def click(self) -> None:
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     401             params = {}
#     402         params["id"] = self._id
# --> 403         return self._parent.execute(command, params)
#     404
#     405     def find_element(self, by=By.ID, value=None) -> WebElement:
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     436                 params["sessionId"] = self.session_id
#     437
# --> 438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
#     440             self.error_handler.check_response(response)
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     288         data = utils.dump_json(params)
#     289         url = f"{self._url}{path}"
# --> 290         return self._request(command_info[0], url, body=data)
#     291
#     292     def _request(self, method, url, body=None):
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     309
#     310         if self.keep_alive:
# --> 311             response = self._conn.request(method, url, body=body, headers=headers)
#     312             statuscode = response.status
#     313         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      72
#      73         if method in self._encode_url_methods:
# ---> 74             return self.request_encode_url(
#      75                 method, url, fields=fields, headers=headers, **urlopen_kw
#      76             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      94             url += "?" + urlencode(fields)
#      95
# ---> 96         return self.urlopen(method, url, **extra_kw)
#      97
#      98     def request_encode_body(
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     374             response = conn.urlopen(method, url, **kw)
#     375         else:
# --> 376             response = conn.urlopen(method, u.request_uri, **kw)
#     377
#     378         redirect_location = redirect and response.get_redirect_location()
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# C:\ProgramData\Anaconda3\lib\http\client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# C:\ProgramData\Anaconda3\lib\http\client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
print("sayfa sayısı: page_count" )
# Out:
# sayfa sayısı:`page_count`

# %%
sayfa = int(page_count)
print(page_count)
type(page_count)
deneme = sayfa+23
print(deneme)
# Out:
# 350
# 373

# %%
import time
import requests 
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from selenium import webdriver
import pandas as pd
from tqdm import tqdm
import webbrowser

# %%
df = pd.DataFrame()
print(df)
df['deneme'] = []
print(df)
df.drop('deneme',axis=1, inplace=True)
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: [deneme]
# Index: []
# Empty DataFrame
# Columns: []
# Index: []

# %%
baslik = input("Aranan kelime?")

url = "https://www.eksisozluk.com/"
webbrowser.open_new_tab(url)
#url = "https://eksisozluk.com/"
#browser = webdriver.Chrome()
time.sleep(1)
print("1")
browser.get(url)
print("2")
time.sleep(3)
input_area = browser.find_element(By.ID,"search-textbox")
print("3")
button = browser.find_element(By.XPATH,"//*[@id='search-form']/button")
print("4")
time.sleep(3)
input_area.send_keys(baslik)
print("5")
time.sleep(2)
button.click()
time.sleep(3)
url = browser.current_url
source = browser.page_source
soup = BeautifulSoup(source, "html.parser")
try:
    page_count = len(soup.find("div", {"class": "clearfix sub-title-container"}).find(
        "div", {"class": "pager"}).find_all("option"))
except:
    page_count = 1
print(page_count)

text=[]
authors=[]

headers = {
    'User-Agent': "Mozilla/5.0 (Macintosh; Intel Mac os X 10_14_6) AppleMebkit/605.1.15 (KHTML, like Gecko) Version/13.0.1 Safari/605.1.15"}
for i in tqdm(range(1, page_count + 1)):
    response = requests.get(url + "?p=" + str(i), headers=headers)
    #print(url + "?p=" + str(i))
    time.sleep(2)
    soup = BeautifulSoup(response. content, "html.parser")
    entry_divs = soup.find_all("div", {"class": "content"})
    for entry in entry_divs:
        print(entry.text)
        text.append(entry.text)
        footer = entry.findNext("footer")
        author = footer.find_all("a")[0].text
        print("yazar: " + author)
        authors.append(author)
        

browser.close()
# Out:
# Aranan kelime?tr
# 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5828\757095897.py in <module>
#       7 time.sleep(1)
#       8 print("1")
# ----> 9 browser.get(url)
#      10 print("2")
#      11 time.sleep(3)
#
# NameError: name 'browser' is not defined

# %%
#Listelerimi dataframe e aktarıyorum.
df = pd.DataFrame(list(zip(text, authors)), columns=["text", "authors"])
print(df)
# Out:
#                                                    text           authors
# 0               \r\n    (bkz: seninle iki dakika)\r\n                 uur
# 1     \r\n    ku$kusuz turkiye'nin en buyuk ve en gu...             cyrus
# 2                      \r\n    (bkz: turkcellgol)\r\n            portakal
# 3     \nkaramehmet ve finlandiyali sonera ortakligin...              kris
# 4     \r\n    hedecell, hodocell tarzı ürün/servis i...         esekherif
# ...                                                 ...               ...
# 7645  \r\n    3 yıl önce sahte bir arge reklamıyla d...            quirah
# 7646  \r\n    ankara'nın merkezi muhitlerinden birin...         jamescody
# 7647  \r\n    müşterilerimin güvenini kaybetmektense...      dasdeutscher
# 7648  \r\n    çok değil 2 ay sonra iç anadolu'da köy...  karpuzcu jenkins
# 7649  \r\n    senelerdir diğer iki rakibi gibi vıcık...       jake epping
#
# [7650 rows x 2 columns]

# %%
df.to_excel("turkcell hatlarımızı iptal ediyoruz kampanyası.xlsx",index=False)
